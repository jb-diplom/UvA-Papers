# %%
# %%time
print("test")
# Out:
# test
# Wall time: 0 ns

# %%
# %%time
import importlib
importlib.import_module("topicmap")
from topicmap import *
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <timed exec> in <module>
#
# D:\Janice\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# D:\Janice\anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# D:\Janice\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# D:\Janice\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# D:\Janice\anaconda3\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# D:\Janice\anaconda3\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# D:\Janice\anaconda3\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# D:\Janice\github\UvA-Papers\bigdata\project\topicmaps\topicmap.py in <module>
#      25
#      26 import importlib
# ---> 27 importlib.import_module("reader")
#      28 from reader import loadAllFeedsFromFile,getStringContents, getAllTags
#      29 # importlib.import_module("rssreader.reader")
#
# D:\Janice\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# D:\Janice\anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# D:\Janice\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# D:\Janice\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'reader'

# %%
import numpy as np

from bokeh.io import  show, output_notebook #output_file,
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.plotting import figure
from bokeh.sampledata.stocks import AAPL
output_notebook()
#output_file("tools_hover_tooltip_formatting.html")

def datetime(x):
    return np.array(x, dtype=np.datetime64)

source = ColumnDataSource(data={
    'date'      : datetime(AAPL['date'][::10]),
    'adj close' : AAPL['adj_close'][::10],
    'volume'    : AAPL['volume'][::10],
})

p = figure(plot_height=250, x_axis_type="datetime", tools="", toolbar_location=None,
           title="Hover Tooltip Formatting", sizing_mode="scale_width")
p.background_fill_color="#f5f5f5"
p.grid.grid_line_color="white"
p.xaxis.axis_label = 'Date'
p.yaxis.axis_label = 'Price'
p.axis.axis_line_color = None

p.line(x='date', y='adj close', line_width=2, color='#ebbd5b', source=source)

p.add_tools(HoverTool(
    tooltips=[
        ( 'date',   '@date{%F}'            ),
        ( 'close',  '$@{adj close}{%0.2f}' ), # use @{ } for field names with spaces
        ( 'volume', '@volume{0.00 a}'      ),
    ],

    formatters={
        'date'      : 'datetime', # use 'datetime' formatter for 'date' field
        'adj close' : 'printf',   # use 'printf' formatter for 'adj close' field
                                  # use default 'numeral' formatter for other fields
    },

    # display a tooltip whenever the cursor is vertically in line with a glyph
    mode='vline'
))
# %%time
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1344">Loading BokehJS ...</span>
#     </div>
# UsageError: Line magic function `%%time` not found.
